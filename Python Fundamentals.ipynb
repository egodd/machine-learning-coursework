# %% [markdown]
# # Lecture 3: Learning Python
# Let's take a look the following example codes

# %% [markdown]
# Learning by doing is mostly effective when learning a programming language.
#
# Trial and errors through hands-on experience might be the best way.
#
# However, there are some concepts in Python that could be more tricky or harder to learn from experience-based learning.

# %% [markdown]
# # Today's objective
# 1. Learn Functions and corresponding terminologies
# 2. Understand Objects and Classes

# %% [markdown]
# # 1. Functions
#
# A function can take any number and type of input _parameters_ and return any number and type of output _results_.
#
# Let’s take things one step at a time, and first define and call a function that has no parameters. Here’s the simplest Python function:

# %%
def this_is_a_function():
  pass

# %%
def this_is_a_function():
# Out:
#   File "<ipython-input-4-4b31d39ab2b1>", line 1
#     def this_is_a_function():
#                              ^
# SyntaxError: unexpected EOF while parsing

# %% [markdown]
# - Even for a function with no parameters like this one, you still need the parentheses and the colon in its definition.
# - The next line needs to be indented.
# - Python requires the pass statement to show that this function does nothing (like a blank page)

# %%
# You call this function just by typing its name and parentheses.
this_is_a_function()
# this functions does nothing

# %%
def make_a_noise():
  print('Yey')

make_a_noise()
# Out:
# Yey

# %% [markdown]
# - When you called the make_a_noise() function, Python ran the code inside its definition. In this case, it printed a single word and returned to the main program.

# %%
# Let’s try a function that has no parameters but returns a value:
def agree():
  return True

agree()
# Out:
# True

# %% [markdown]
# ## 1.1 Arguments and Parameters
#
# See the following functions

# %%
def echo(anything):
  return anything + ' ' + anything

# %%
echo('Moon at Noon')
# Out:
# 'Moon at Noon Moon at Noon'

# %%
echo()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-f0a04fb5497a> in <module>
# ----> 1 echo()
#
# TypeError: echo() missing 1 required positional argument: 'anything'

# %% [markdown]
#  - the function echo() was called with the _argument_ string 'Moon at Noon'
#  - This value was copied within echo() to the _parameter_ anything, and then returned (in this case doubled, with a space) to the caller.

# %%
echo(anything = 'Moon at Noon')
# Out:
# 'Moon at Noon Moon at Noon'

# %% [markdown]
# A function can take any number of input arguments (including zero) of any type. It can return any number of output results (also including zero) of any type. If a function doesn’t call return explicitly, the caller gets the result _None_.

# %%
print(this_is_a_function())
# Out:
# None

# %% [markdown]
# ## 1.1.1 None is Useful
#
# None is a special Python value that holds a place when there is nothing to say. It is not the same as the boolean value False, although it looks false when evaluated as a boolean

# %%
thing = None

if thing is None:
  print("It's nothing")
else:
  print("It's something")
# Out:
# It's nothing

# %% [markdown]
# This seems like a subtle distinction, but it’s important in Python. You’ll need None to distinguish a missing value from an empty value.

# %% [markdown]
# ## 1.2 Positional Arguments
#
# Python handles function arguments in a manner that’s very flexible, when compared to many languages. The most familiar types of arguments are positional arguments, whose values are copied to their corresponding parameters in order.

# %%
def menu(wine, entree, dessert):
  return {'wine': wine, 'entree': entree, 'dessert': dessert}

# %%
menu('chardonnay', 'chicken', 'cake')
# Out:
# {'wine': 'chardonnay', 'entree': 'chicken', 'dessert': 'cake'}

# %% [markdown]
# Although very common, a downside of positional arguments is that you need to remember the meaning of each position. If we forgot and called menu() with wine as the last argument instead of the first, the meal would be very different:

# %%
menu('beef', 'bagel', 'bordeaux')
# Out:
# {'wine': 'beef', 'entree': 'bagel', 'dessert': 'bordeaux'}

# %% [markdown]
# ### 1.2.1 Keyword Arguments
#
# To avoid positional argument confusion, you can specify arguments by the names of their corresponding parameters, even in a different order from their definition in the function:

# %%
menu(entree='beef', dessert='bagel', wine='bordeaux')
# Out:
# {'wine': 'bordeaux', 'entree': 'beef', 'dessert': 'bagel'}

# %% [markdown]
# You can mix positional and keyword arguments. Let’s specify the wine first, but use keyword arguments for the entree and dessert:

# %%
menu('frontenac', dessert='flan', entree='fish')
# Out:
# {'wine': 'frontenac', 'entree': 'fish', 'dessert': 'flan'}

# %% [markdown]
# ## 1.3 Specify Default Parameter Values
#
# You can specify default values for parameters. The default is used if the caller does not provide a corresponding argument. This bland-sounding feature can actually be quite useful. Using the previous example:

# %%
def menu(wine, entree, dessert='pudding'):
  return {'wine': wine, 'entree': entree, 'dessert': dessert}

# %%
menu('chardonnay', 'chicken')
# Out:
# {'wine': 'chardonnay', 'entree': 'chicken', 'dessert': 'pudding'}

# %% [markdown]
# If you do provide an argument, it’s used instead of the default:

# %%
menu('dunkelfelder', 'duck', 'doughnut')
# Out:
# {'wine': 'dunkelfelder', 'entree': 'duck', 'dessert': 'doughnut'}

# %% [markdown]
# ## 1.6 Handle Errors with try and except

# %% [markdown]
# In some languages, errors are indicated by special function return values. When things go south, Python uses exceptions: code that is executed when an associated error occurs.

# %%
short_list = [1, 2, 3]
position = 5
short_list[position]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-22-f5eaf9cc45f2> in <module>
#       1 short_list = [1, 2, 3]
#       2 position = 5
# ----> 3 short_list[position]
#
# IndexError: list index out of range

# %% [markdown]
# Rather than leaving things to chance, use *try* to wrap your code, and *except* to provide the error handling:

# %%
short_list = [1, 2, 3]
position = 5
try:
  short_list[position]
except:
  print('Need a position between 0 and', len(short_list)-1, ' but got', position)
# Out:
# Need a position between 0 and 2  but got 5

# %% [markdown]
# The code inside the *try* block is run. If there is an error, an exception is raised and the code inside the *except* block runs. If there are no errors, the except block is skipped.

# %% [markdown]
# # 2. Objects and Classes

# %% [markdown]
# An *object* is a custom data structure containing both data (variables, called *attributes*) and code (functions, called *methods*). It represents a unique instance of some concrete thing. Think of objects as nouns and their methods as verbs. An object represents an individual thing, and its methods define how it interacts with other things

# %% [markdown]
# ## Quiz:
#
# Create a Python class called "Car" that has the following attributes:
# - make (string)
# - model (string)
# - year (integer)
# - num_doors (integer)
#
# The class should also have the following methods:
# - honk(self) - prints "Honk honk!"
# - get_info(self) - returns a string in the format "The car is a make model year with num_doors doors."
# - drive(self, distance) - prints "The car drove distance miles."
#
# Create an instance of the Car class with the following attributes:
# - make: "Toyota"
# - model: "Camry"
# - year: 2020
# - num_doors: 4
#
# Then, call the honk(), get_info(), and drive(50) methods on the instance and print the result of the get_info() method.

# %% [markdown]
# ------------------
# To create your own custom object in Python, you first need to define a class by using the class keyword. Let’s walk through some simple examples.
#
# Suppose that you want to define objects to represent information about cats. Each object will represent one feline. You’ll first want to define a class called *Cat*. In the examples that follow, we try more than one version of this class as we build up from the simplest class to ones that actually do something useful.

# %%
example = [3,2,1]
sorted(example)
# Out:
# [1, 2, 3]

# %%
example.sort()
example
# Out:
# [1, 2, 3]

# %%
class Cat():
  pass

# %% [markdown]
# or

# %%
class Cat:
  pass

# %% [markdown]
# Just as with functions, we needed to say pass to indicate that this class was empty. This definition is the bare minimum to create an object.
#
# You create an object from a class by calling the class name as though it were a function:

# %%
a_cat = Cat()
b_cat = Cat()

# %% [markdown]
# ## 2.1 Attributes
#
# Ask yourself. What is an *Attribute*? Can you distinguish between attribute and method?

# %% [markdown]
# An *attribute* is a variable inside a class or object. During and after an object or class is created, you can assign attributes to it. An attribute can be any other object.
#
# Let's assign a few attributes to the object:

# %%
a_cat.age = 3
a_cat.name = 'Totoro'
a_cat.nemesis = b_cat

# %%
a_cat.age
# Out:
# 3

# %%
a_cat.name
# Out:
# 'Totoro'

# %%
a_cat.nemesis

# %%
b_cat

# %% [markdown]
# Even the simplest object like this one can be used to store multiple attributes.

# %% [markdown]
# -------------------
# ## 2.2 Methods
#
# A *method* is a function in a class or object. A method looks like any other function, but can be used in special ways.

# %% [markdown]
# ### Initialization
#
# If you want to assign object attributes at creation time, you need the special Python object initialization method

# %%
class Cat:
  def __init__(self):
    pass

# %% [markdown]
# - *\__init\__*() is the special Python name for a method that initializes an individual object from its class definition
# - self argument specifies that it refers to the individual object itself

# %% [markdown]
# When you define \__init\__() in a class definition, its first parameter should be named self. Although self is not a reserved word in Python, it’s common usage.

# %%
class Cat:
  def __init__(self, name):
    self.name = name

# %%
furball = Cat()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-36-5f61a3698db2> in <module>
# ----> 1 furball = Cat()
#
# TypeError: __init__() missing 1 required positional argument: 'name'

# %%
def cat(name):
  pass
cat()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-37-f4be93c333d6> in <module>
#       1 def cat(name):
#       2   pass
# ----> 3 cat()
#
# TypeError: cat() missing 1 required positional argument: 'name'

# %%
furball = Cat('Grumpy')

# %% [markdown]
# Here's what is happening behind:
#
#   - Looks up the definition of the Cat class
#   - Instantiates (creates) a new object in memory
#   - Calls the object’s \__init__() method, passing this newly created object as self and the other argument ('Grumpy') as name
#   - Stores the value of name in the object
#   - Returns the new object
#   - Attaches the variable furball to the object

# %%
furball

# %%
furball.name
# Out:
# 'Grumpy'

# %% [markdown]
# Think of \__init__() as an initializer.

# %% [markdown]
# -----------------
# ### Quiz revisit
#
# Create a Python class called "Car" that has the following attributes:
# - make (string)
# - model (string)
# - year (integer)
# - num_doors (integer)
#
# The class should also have the following methods:
# - honk(self) - prints "Honk honk!"
# - get_info(self) - returns a string in the format "The car is a make model year with num_doors doors."
# - drive(self, distance) - prints "The car drove distance miles."
#
# Create an instance of the Car class with the following attributes:
# - make: "Toyota"
# - model: "Camry"
# - year: 2020
# - num_doors: 4
#
# Then, call the honk(), get_info(), and drive(50) methods on the instance and print the result of the get_info() method.
#
# --------------
#
# Let's first to define attributes

# %%
class Car:
    def __init__(self, make, model, year, num_doors):
        self.make = make
        self.model = model
        self.year = year
        self.num_doors = num_doors

# %%
car = Car("Toyota", "Camry", 2020, 4)

# %%
car.make
# Out:
# 'Toyota'

# %%
car.year
# Out:
# 2020

# %%
class Car:
    def __init__(self, make, model, year, num_doors):
        self.make = make
        self.model = model
        self.year = year
        self.num_doors = num_doors

    def honk(self):
        print("Honk honk!")

    def get_info(self):
        return f"The car is a {self.make} {self.model} {self.year} with {self.num_doors} doors."

    def drive(self, distance):
        print(f"The car drove {distance} miles.")

# %%
car = Car("Toyota", "Camry", 2020, 4)
car.honk()
print(car.get_info())
car.drive(50)
# Out:
# Honk honk!
# The car is a Toyota Camry 2020 with 4 doors.
# The car drove 50 miles.

# %% [markdown]
# If you are familiar with {}.format style strings, you'd better to learn f-strings:
#
# https://realpython.com/python-f-strings/#python-f-strings-the-pesky-details

# %% [markdown]
# ## Some advanced example: Chaotic dynamics

# %% [markdown]
# You can find this example:
# https://python-programming.quantecon.org/python_oop.html
#
# Let’s look at one more example, related to chaotic dynamics in nonlinear systems.
#
# A simple transition rule that can generate erratic time paths is the logistic map
#
# $$x_{t+1}=r x_t (1-x_t),\;x_0\in[0,1],\;r\in [0,4]$$

# %%
class Chaos:
  """
  Models the dynamical system :math:`x_{t+1} = r x_t (1 - x_t)`
  """
  def __init__(self, x0, r):
      """
      Initialize with state x0 and parameter r
      """
      self.x, self.r = x0, r

  def update(self):
      "Apply the map to update state."
      self.x =  self.r * self.x *(1 - self.x)

  def generate_sequence(self, n):
      "Generate and return a sequence of length n."
      path = []
      for i in range(n):
          path.append(self.x)
          self.update()
      return path

# %%
ch = Chaos(.1,4)

# %%
ch.x
# Out:
# 0.1

# %%
ch.r
# Out:
# 4

# %%
ch.generate_sequence(5)
# Out:
# [0.1, 0.36000000000000004, 0.9216, 0.28901376000000006, 0.8219392261226498]

# %%
import matplotlib.pyplot as plt
ch = Chaos(0.1, 4.0)
ts_length = 250

fig, ax = plt.subplots()
ax.set_xlabel('$t$', fontsize=14)
ax.set_ylabel('$x_t$', fontsize=14)
x = ch.generate_sequence(ts_length)
ax.plot(range(ts_length), x, 'bo-', alpha=0.5, lw=2, label='$x_t$')
plt.show()

# %% [markdown]
# ## 2.3 Inheritance
#
# When you’re trying to solve some coding problem, often you’ll find an existing class that creates objects that do almost what you need. What can you do?
#
# One solution is inheritance: creating a new class from an existing class, but with some additions or changes. It’s a good way to reuse code. It is a critical component of neural nets.

# %% [markdown]
# ### Inherit from a Parent Class

# %% [markdown]
# You define only what you need to add or change in the new class, and this overrides the behavior of the old class. The original class is called a parent, superclass, or base class; the new class is called a child, subclass, or derived class. These terms are interchangeable in object-oriented programming.

# %%
class Car():
  pass

class BMW(Car):
  pass

# %% [markdown]
# We define an empty class called Car. Next, we define a subclass of Car called BMW. You define a subclass by using the same class keyword but with the parent class name inside the parentheses

# %%
issubclass(BMW, Car)
# Out:
# True

# %%
issubclass(Car, BMW)
# Out:
# False

# %% [markdown]
# Let's create objects.

# %%
give_me_a_car = Car()
give_me_a_BMW = BMW()

# %% [markdown]
# The object named give_me_a_BMW is an instance of class BMW, but it also inherits whatever a Car can do.

# %%
class Car():
  def exclaim(self):
    print("I'm a Car!")

class BMW(Car):
  pass

# %%
give_me_a_car = Car()
give_me_a_BMW = BMW()

give_me_a_car.exclaim()
give_me_a_BMW.exclaim()
# Out:
# I'm a Car!
# I'm a Car!

# %% [markdown]
# As you just saw, a new class initially inherits everything from its parent class. Moving forward, you’ll see how to replace or override a parent method.

# %%
class Car():
  def exclaim(self):
    print("I'm a Car!")

class BMW(Car):
    def exclaim(self):
     print("Yes, I'm a Car, but I don't want to be grouped with you.")

# %%
give_me_a_car = Car()
give_me_a_BMW = BMW()

give_me_a_car.exclaim()
give_me_a_BMW.exclaim()
# Out:
# I'm a Car!
# Yes, I'm a Car, but I don't want to be grouped with you.

# %%
class Car():
  def exclaim(self):
    print("I'm a Car!")

class BMW(Car):
    def exclaim(self):
      print("Yes, I'm a Car, but I don't want to be grouped with you.")
    def need_a_help(self):
      print('Do you need a help?')

# %%
give_me_a_car = Car()
give_me_a_BMW = BMW()

give_me_a_BMW.need_a_help()
# Out:
# Do you need a help?

# %%
give_me_a_car.need_a_help()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-63-50be9d3b6048> in <module>
# ----> 1 give_me_a_car.need_a_help()
#
# AttributeError: 'Car' object has no attribute 'need_a_help'

# %% [markdown]
# We saw how the child class could add or override a method from the parent. What if it wanted to call that parent method?
#
# We can use super() in the child class

# %%
class Person():
  def __init__(self, name):
    self.name = name

class EmailPerson(Person):
  def __init__(self, name, email):
    super().__init__(name)
    self.email = email

# %% [markdown]
# When you define an \__init__() method for your class, you’re replacing the \__init__() method of its parent class, and the latter is not called automatically anymore. As a result, we need to call it explicitly. Here’s what’s happening:
#
#   - The super() gets the definition of the parent class, Person.
#
#   - The \__init__() method calls the Person.\__init__() method. It takes care of passing the self argument to the superclass, so you just need to give it any optional arguments. In our case, the only other argument Person() accepts is name.
#
#   - The self.email = email line is the new code that makes this EmailPerson different from a Person.

# %%
bob = EmailPerson('Bob Frapples', 'bob@frapples.com')

# %%
bob

# %%
bob.name
# Out:
# 'Bob Frapples'

# %% [markdown]
# Consider: why didn't we just define our new class as follows?

# %%
class EmailPerson(Person):
  def __init__(self, name, email):
    self.name = name
    self.email = email

# %% [markdown]
# We could have done that, but it would have defeated our use of inheritance. We used super() to make Person do its work, the same as a plain Person object would. There’s another benefit: if the definition of Person changes in the future, using super() will ensure that the attributes and methods that EmailPerson inherits from Person will reflect the change.
#
# Use super() when the child is doing something its own way but still needs something from the parent (as in real life).
